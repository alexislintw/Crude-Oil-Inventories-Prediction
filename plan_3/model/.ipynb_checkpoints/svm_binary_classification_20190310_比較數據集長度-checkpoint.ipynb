# %% [markdown]
# - oil (1982/8/20 ~ 今 )
# - 用6個數值預測隔週存貨漲跌
# - 前80%做training set (非亂數)
# - SVM 2元分類
# - 指標值分2類

# %%
import numpy as np
import pandas as pd
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
filename = "../dataset/weekly_supply_estimates_19820820.csv"
df = pd.read_csv(filename)
Y_all = df['Label_D6-AB'].values
X_all = df.drop(['Date','D6-D','D6-E','D6-AB','Label_D6-E','Label_D6-S','Label_D6-AB'], 1)
X_all = np.array(X_all)
Y_all = np.array(Y_all)
print(X_all.shape)
print(Y_all.shape)
# Out:
# (1899, 6)
# (1899,)

# %%
def train_predict(x_all,y_all):
    test_size = 0.2
    train_size = int(len(x_all)*(1-test_size))
    X_train = x_all[0:train_size] 
    X_test = x_all[train_size:]
    y_train = y_all[0:train_size]
    y_test = y_all[train_size:]
    X_train, XX_test, y_train, yy_test = train_test_split(X_train, y_train, test_size=0, random_state=42)
    #X_train, X_test, y_train, y_test = train_test_split(x_all, y_all, test_size=0.2, random_state=42)
    print(X_train.shape)
    print(X_test.shape)
    #clf = SVC() 
    clf = RandomForestClassifier(criterion='entropy',n_estimators=300,max_depth=9, random_state=0)
    print( "Training a {} using a training set size of {}. . .".format(clf.__class__.__name__, len(X_train)) )    
    clf.fit(X_train, y_train)
    y_pred_train = clf.predict(X_train)
    y_pred_test = clf.predict(X_test)
    score_train = accuracy_score(y_train, y_pred_train)
    score_test = accuracy_score(y_test, y_pred_test)
    print( "Accuracy for training set: {:.4f}.".format(score_train) )
    print( "Accuracy for test set: {:.4f}.".format(score_test) )
    return (score_train,score_test)

# %%
start_week_num = []
result_train = []
result_test = []
for i in range(30):
    start = i*50
    x_all = X_all[start:]
    y_all = Y_all[start:]
    start_week_num.append(start)
    (score_train,score_test) = train_predict(x_all,y_all)
    result_train.append(score_train)
    result_test.append(score_test)
# Out:
# (1519, 6)
# (380, 6)
# Training a RandomForestClassifier using a training set size of 1519. . .
# Accuracy for training set: 0.5806.
# Accuracy for test set: 0.5895.
# (1479, 6)
# (370, 6)
# Training a RandomForestClassifier using a training set size of 1479. . .
# Accuracy for training set: 0.5801.
# Accuracy for test set: 0.5919.
# (1439, 6)
# (360, 6)
# Training a RandomForestClassifier using a training set size of 1439. . .
# Accuracy for training set: 0.5823.
# Accuracy for test set: 0.5917.
# (1399, 6)
# (350, 6)
# Training a RandomForestClassifier using a training set size of 1399. . .
# Accuracy for training set: 0.5861.
# Accuracy for test set: 0.5943.
# (1359, 6)
# (340, 6)
# Training a RandomForestClassifier using a training set size of 1359. . .
# Accuracy for training set: 0.5909.
# Accuracy for test set: 0.6088.
# (1319, 6)
# (330, 6)
# Training a RandomForestClassifier using a training set size of 1319. . .
# Accuracy for training set: 0.5974.
# Accuracy for test set: 0.5848.
# (1279, 6)
# (320, 6)
# Training a RandomForestClassifier using a training set size of 1279. . .
# Accuracy for training set: 0.6005.
# Accuracy for test set: 0.5875.
# (1239, 6)
# (310, 6)
# Training a RandomForestClassifier using a training set size of 1239. . .
# Accuracy for training set: 0.6069.
# Accuracy for test set: 0.6000.
# (1199, 6)
# (300, 6)
# Training a RandomForestClassifier using a training set size of 1199. . .
# Accuracy for training set: 0.6080.
# Accuracy for test set: 0.5733.
# (1159, 6)
# (290, 6)
# Training a RandomForestClassifier using a training set size of 1159. . .
# Accuracy for training set: 0.6074.
# Accuracy for test set: 0.5966.
# (1119, 6)
# (280, 6)
# Training a RandomForestClassifier using a training set size of 1119. . .
# Accuracy for training set: 0.6050.
# Accuracy for test set: 0.5857.
# (1079, 6)
# (270, 6)
# Training a RandomForestClassifier using a training set size of 1079. . .
# Accuracy for training set: 0.6061.
# Accuracy for test set: 0.5815.
# (1039, 6)
# (260, 6)
# Training a RandomForestClassifier using a training set size of 1039. . .
# Accuracy for training set: 0.6112.
# Accuracy for test set: 0.6038.
# (999, 6)
# (250, 6)
# Training a RandomForestClassifier using a training set size of 999. . .
# Accuracy for training set: 0.6106.
# Accuracy for test set: 0.6240.
# (959, 6)
# (240, 6)
# Training a RandomForestClassifier using a training set size of 959. . .
# Accuracy for training set: 0.6100.
# Accuracy for test set: 0.6250.
# (919, 6)
# (230, 6)
# Training a RandomForestClassifier using a training set size of 919. . .
# Accuracy for training set: 0.6126.
# Accuracy for test set: 0.6217.
# (879, 6)
# (220, 6)
# Training a RandomForestClassifier using a training set size of 879. . .
# Accuracy for training set: 0.6200.
# Accuracy for test set: 0.6000.
# (839, 6)
# (210, 6)
# Training a RandomForestClassifier using a training set size of 839. . .
# Accuracy for training set: 0.6246.
# Accuracy for test set: 0.6000.
# (799, 6)
# (200, 6)
# Training a RandomForestClassifier using a training set size of 799. . .
# Accuracy for training set: 0.6258.
# Accuracy for test set: 0.6150.
# (759, 6)
# (190, 6)
# Training a RandomForestClassifier using a training set size of 759. . .
# Accuracy for training set: 0.6337.
# Accuracy for test set: 0.6263.
# (719, 6)
# (180, 6)
# Training a RandomForestClassifier using a training set size of 719. . .
# Accuracy for training set: 0.6384.
# Accuracy for test set: 0.6278.
# (679, 6)
# (170, 6)
# Training a RandomForestClassifier using a training set size of 679. . .
# Accuracy for training set: 0.6539.
# Accuracy for test set: 0.6176.
# (639, 6)
# (160, 6)
# Training a RandomForestClassifier using a training set size of 639. . .
# Accuracy for training set: 0.6651.
# Accuracy for test set: 0.5875.
# (599, 6)
# (150, 6)
# Training a RandomForestClassifier using a training set size of 599. . .
# Accuracy for training set: 0.6678.
# Accuracy for test set: 0.5867.
# (559, 6)
# (140, 6)
# Training a RandomForestClassifier using a training set size of 559. . .
# Accuracy for training set: 0.6655.
# Accuracy for test set: 0.6429.
# (519, 6)
# (130, 6)
# Training a RandomForestClassifier using a training set size of 519. . .
# Accuracy for training set: 0.6667.
# Accuracy for test set: 0.6846.
# (479, 6)
# (120, 6)
# Training a RandomForestClassifier using a training set size of 479. . .
# Accuracy for training set: 0.6681.
# Accuracy for test set: 0.6417.
# (439, 6)
# (110, 6)
# Training a RandomForestClassifier using a training set size of 439. . .
# Accuracy for training set: 0.6697.
# Accuracy for test set: 0.6455.
# (399, 6)
# (100, 6)
# Training a RandomForestClassifier using a training set size of 399. . .
# Accuracy for training set: 0.6642.
# Accuracy for test set: 0.6500.
# (359, 6)
# (90, 6)
# Training a RandomForestClassifier using a training set size of 359. . .
# Accuracy for training set: 0.6852.
# Accuracy for test set: 0.6111.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(start_week_num,result_train,label='training set')
plt.plot(start_week_num,result_test,label='testing set')
plt.legend()
plt.xlabel('Week Number of Start')
plt.ylabel('Accuracy')
plt.show()
